# %%
import pandas as pd
import numpy as np
import re
import csv
import pprint
from collections import Counter
import dedupe

# %%
# Read original csv file
df = pd.read_csv('restaurant-training.csv', skip_blank_lines=True)
df = df.drop(columns=['phone', 'cluster'])
df = df.fillna('')
# Add an id column to each row
df['id'] = list(range(len(df)))
df
# Out:
#                    name                                   addr  \
# 0        locanda veneta                                3rd st.
# 1        locanda veneta                      8638 w. third st.
# 2        locanda veneta                             8638 w 3rd
# 3             cafe lalo                        201 w. 83rd st.
# 4             cafe lalo                        201 w. 83rd st.
# 5        les celebrites                     160 central park s
# 6        les celebrites                        155 w. 58th st.
# 7    second avenue deli               156 2nd ave. at 10th st.
# 8    second avenue deli                        156 second ave.
# 9     smith & wollensky                        201 e. 49th st.
# 10    smith & wollensky                         797 third ave.
# 11               chin's                 3200 las vegas blvd. s
# 12               chin's                3200 las vegas blvd. s.
# 13             toulouse                        b peachtree rd.
# 14             toulouse                    293-b peachtree rd.
# 15         rose pistola                      532 columbus ave.
# 16         rose pistola                      532 columbus ave.
# 17        bistro garden                       176 n. canon dr.
# 18                 remi                      3rd st. promenade
# 19                 remi                        145 w. 53rd st.
# 20                 west  63rd street steakhouse 44 w. 63rd st.
# 21               bistro                 3400 las vegas blvd. s
# 22               mikado                 3400 las vegas blvd. s
# 23  l'osteria del forno                      519 columbus ave.
# 24                stars                      150 redwood alley
# 25           stars cafe                      500 van ness ave.
# 26       belvedere  the         9882 little santa monica blvd.
# 27            bernard's                       515 s. olive st.
# 28            bistro 45                      45 s. mentor ave.
# 29            cafe '50s                      838 lincoln blvd.
# 30           cafe blanc         9777 little santa monica blvd.
# 31          la cachette        10506 little santa monica blvd.
# 32             moongate                3400 las vegas blvd. s.
#
#               city              type  id
# 0      los angeles           italian   0
# 1      los angeles           italian   1
# 2   st los angeles           italian   2
# 3         new york        coffee bar   3
# 4    new york city      coffeehouses   4
# 5         new york            french   5
# 6    new york city  french (classic)   6
# 7         new york      delicatessen   7
# 8    new york city             delis   8
# 9         new york          american   9
# 10   new york city       steakhouses  10
# 11       las vegas             asian  11
# 12       las vegas           chinese  12
# 13         atlanta            french  13
# 14         atlanta      french (new)  14
# 15   san francisco           italian  15
# 16   san francisco           italian  16
# 17     los angeles       californian  17
# 18    santa monica           italian  18
# 19        new york           italian  19
# 20        new york          american  20
# 21       las vegas       continental  21
# 22       las vegas             asian  22
# 23   san francisco           italian  23
# 24   san francisco          american  24
# 25   san francisco          american  25
# 26   beverly hills  pacific new wave  26
# 27     los angeles       continental  27
# 28        pasadena       californian  28
# 29          venice          american  29
# 30   beverly hills  pacific new wave  30
# 31    century city      french (new)  31
# 32       las vegas           chinese  32

# %%
irrelevant_regex = re.compile(r'[^a-z0-9\s]')
multispace_regex = re.compile(r'\s\s+')

# %%
# Cleaning the name column
def assign_no_symbols_name(df):
    return df.assign(
        name=df['name']
             .str.replace(irrelevant_regex, ' ', regex=True)
             .str.replace(multispace_regex, ' ', regex=True))

# %%
possible_stopwords = Counter(' '.join(df['name']).split()).most_common(20)
pprint.pprint(possible_stopwords)
# Out:
# [('cafe', 5),
#  ('locanda', 3),
#  ('veneta', 3),
#  ('bistro', 3),
#  ('lalo', 2),
#  ('les', 2),
#  ('celebrites', 2),
#  ('second', 2),
#  ('avenue', 2),
#  ('deli', 2),
#  ('smith', 2),
#  ('&', 2),
#  ('wollensky', 2),
#  ("chin's", 2),
#  ('toulouse', 2),
#  ('rose', 2),
#  ('pistola', 2),
#  ('remi', 2),
#  ('stars', 2),
#  ('garden', 1)]

# %%
# Deleting stopwords
def assign_cleaned_name(df):
    restaurant_stopwords = {
        's', 'the', 'la', 'le', 'of', 'and', 'on', 'l'}
    restaurant_stopwords_regex = r'\b(?:{})\b'.format(
        '|'.join(restaurant_stopwords))
    return df.assign(
        name=df['name']
             .str.replace(restaurant_stopwords_regex, '', regex=True)
             .str.replace(multispace_regex, ' ', regex=True)
             .str.strip())

# %%
df = assign_no_symbols_name(df)
df = assign_cleaned_name(df)
df.head(5)
# Out:
#              name               addr            city          type  id
# 0  locanda veneta            3rd st.     los angeles       italian   0
# 1  locanda veneta  8638 w. third st.     los angeles       italian   1
# 2  locanda veneta         8638 w 3rd  st los angeles       italian   2
# 3       cafe lalo    201 w. 83rd st.        new york    coffee bar   3
# 4       cafe lalo    201 w. 83rd st.   new york city  coffeehouses   4

# %%
# Dedupe configuration
fields = [
    {
        'field': 'name',
        'variable name': 'name',
        'type': 'ShortString',
        'has missing': True
    },
    {
        'field': 'addr',
        'variable name': 'addr',
        'type': 'ShortString',
    },
    {
        'field': 'city',
        'variable name': 'city',
        'type': 'ShortString',
        'has missing': True
    },
]

# %%
# Deduper initialization
deduper = dedupe.Dedupe(fields, num_cores=4)

# %%
# Formating the data for dedupe
data_for_dedupe = df.to_dict('index')
for record in data_for_dedupe.values():
    # Change nans to None
    for k, v in record.items():
        if isinstance(v, float) and np.isnan(v):
            record[k] = None

# %%
deduper.prepare_training(data_for_dedupe)

# %%
# Manual labeling
dedupe.console_label(deduper)
# Out:
# name : rose pistola
# addr : 532 columbus ave.
# city : san francisco
#
# name : rose pistola
# addr : 532 columbus ave.
# city : san francisco
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# name : chin
# addr : 3200 las vegas blvd. s
# city : las vegas
#
# name : chin
# addr : 3200 las vegas blvd. s.
# city : las vegas
#
# 1/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : toulouse
# addr : b peachtree rd.
# city : atlanta
#
# name : toulouse
# addr : 293-b peachtree rd.
# city : atlanta
#
# 2/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : second avenue deli
# addr : 156 2nd ave. at 10th st.
# city : new york
#
# name : second avenue deli
# addr : 156 second ave.
# city : new york city
#
# 3/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : chin
# addr : 3200 las vegas blvd. s.
# city : las vegas
#
# name : moongate
# addr : 3400 las vegas blvd. s.
# city : las vegas
#
# 4/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : chin
# addr : 3200 las vegas blvd. s
# city : las vegas
#
# name : moongate
# addr : 3400 las vegas blvd. s.
# city : las vegas
#
# 4/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : stars
# addr : 150 redwood alley
# city : san francisco
#
# name : stars cafe
# addr : 500 van ness ave.
# city : san francisco
#
# 4/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : bistro
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# name : bistro 45
# addr : 45 s. mentor ave.
# city : pasadena
#
# 4/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : les celebrites
# addr : 160 central park s
# city : new york
#
# name : les celebrites
# addr : 155 w. 58th st.
# city : new york city
#
# 4/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : smith wollensky
# addr : 201 e. 49th st.
# city : new york
#
# name : smith wollensky
# addr : 797 third ave.
# city : new york city
#
# 4/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : locanda veneta
# addr : 3rd st.
# city : los angeles
#
# name : locanda veneta
# addr : 8638 w 3rd
# city : st los angeles
#
# 4/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : locanda veneta
# addr : 3rd st.
# city : los angeles
#
# name : locanda veneta
# addr : 8638 w. third st.
# city : los angeles
#
# 5/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : remi
# addr : 3rd st. promenade
# city : santa monica
#
# name : remi
# addr : 145 w. 53rd st.
# city : new york
#
# 6/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : locanda veneta
# addr : 3rd st.
# city : los angeles
#
# name : remi
# addr : 3rd st. promenade
# city : santa monica
#
# 6/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : les celebrites
# addr : 155 w. 58th st.
# city : new york city
#
# name : remi
# addr : 145 w. 53rd st.
# city : new york
#
# 6/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : locanda veneta
# addr : 8638 w. third st.
# city : los angeles
#
# name : locanda veneta
# addr : 8638 w 3rd
# city : st los angeles
#
# 6/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : les celebrites
# addr : 155 w. 58th st.
# city : new york city
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 7/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : bistro garden
# addr : 176 n. canon dr.
# city : los angeles
#
# name : bistro
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# 7/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : second avenue deli
# addr : 156 second ave.
# city : new york city
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 7/10 positive, 11/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : les celebrites
# addr : 160 central park s
# city : new york
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 7/10 positive, 12/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : second avenue deli
# addr : 156 2nd ave. at 10th st.
# city : new york
#
# name : remi
# addr : 145 w. 53rd st.
# city : new york
#
# 7/10 positive, 13/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : smith wollensky
# addr : 201 e. 49th st.
# city : new york
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 7/10 positive, 14/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : smith wollensky
# addr : 797 third ave.
# city : new york city
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 7/10 positive, 15/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : cafe lalo
# addr : 201 w. 83rd st.
# city : new york
#
# name : cafe lalo
# addr : 201 w. 83rd st.
# city : new york city
#
# 7/10 positive, 16/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : bistro
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# name : mikado
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# 8/10 positive, 16/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : locanda veneta
# addr : 3rd st.
# city : los angeles
#
# name : west
# addr : 63rd street steakhouse 44 w. 63rd st.
# city : new york
#
# 9/10 positive, 16/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : mikado
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# name : moongate
# addr : 3400 las vegas blvd. s.
# city : las vegas
#
# 9/10 positive, 17/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : bistro
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# name : moongate
# addr : 3400 las vegas blvd. s.
# city : las vegas
#
# 10/10 positive, 17/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : rose pistola
# addr : 532 columbus ave.
# city : san francisco
#
# name : osteria del forno
# addr : 519 columbus ave.
# city : san francisco
#
# 11/10 positive, 17/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : rose pistola
# addr : 532 columbus ave.
# city : san francisco
#
# name : osteria del forno
# addr : 519 columbus ave.
# city : san francisco
#
# 11/10 positive, 18/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# name : chin
# addr : 3200 las vegas blvd. s
# city : las vegas
#
# name : mikado
# addr : 3400 las vegas blvd. s
# city : las vegas
#
# 11/10 positive, 19/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# Finished labeling

# %%
# Begin with the trainig
deduper.train()

# %%
# Shows the rules found during the training
deduper.predicates
# Out:
# (SimplePredicate: (suffixArray, name),
#  SimplePredicate: (wholeFieldPredicate, addr))

# %%
# Clustering

# `partition` will return sets of records that dedupe
# believes are all referring to the same entity.

print('clustering...')
clustered_dupes = deduper.partition(data_for_dedupe, 0.5)

print('# duplicate sets', len(clustered_dupes))
# Out:
# clustering...
# # duplicate sets 27

# %%
clustered_dupes
# Out:
# [((1, 2), array([0.78602743, 0.78602743])),
#  ((3, 4), (0.98323005, 0.98323005)),
#  ((7, 8), (0.8077531, 0.8077531)),
#  ((11, 12), (0.9838027, 0.9838027)),
#  ((13, 14), (0.93425727, 0.93425727)),
#  ((15, 16), (0.9846, 0.9846)),
#  ((0,), (1.0,)),
#  ((5,), (1.0,)),
#  ((6,), (1.0,)),
#  ((9,), (1.0,)),
#  ((10,), (1.0,)),
#  ((17,), (1.0,)),
#  ((18,), (1.0,)),
#  ((19,), (1.0,)),
#  ((20,), (1.0,)),
#  ((21,), (1.0,)),
#  ((22,), (1.0,)),
#  ((23,), (1.0,)),
#  ((24,), (1.0,)),
#  ((25,), (1.0,)),
#  ((26,), (1.0,)),
#  ((27,), (1.0,)),
#  ((28,), (1.0,)),
#  ((29,), (1.0,)),
#  ((30,), (1.0,)),
#  ((31,), (1.0,)),
#  ((32,), (1.0,))]

# %%
# Write our original data back out to a CSV with a new column called
# 'Cluster ID' which indicates which records refer to each other with a confidence score.

cluster_membership = {}
for cluster_id, (records, scores) in enumerate(clustered_dupes):
    for record_id, score in zip(records, scores):
        cluster_membership[record_id] = {
            'Cluster ID': cluster_id,
            'confidence_score': score
        }

# %%
cluster_membership
# Out:
# {1: {'Cluster ID': 0, 'confidence_score': 0.7860274291465319},
#  2: {'Cluster ID': 0, 'confidence_score': 0.7860274291465319},
#  3: {'Cluster ID': 1, 'confidence_score': 0.98323005},
#  4: {'Cluster ID': 1, 'confidence_score': 0.98323005},
#  7: {'Cluster ID': 2, 'confidence_score': 0.8077531},
#  8: {'Cluster ID': 2, 'confidence_score': 0.8077531},
#  11: {'Cluster ID': 3, 'confidence_score': 0.9838027},
#  12: {'Cluster ID': 3, 'confidence_score': 0.9838027},
#  13: {'Cluster ID': 4, 'confidence_score': 0.93425727},
#  14: {'Cluster ID': 4, 'confidence_score': 0.93425727},
#  15: {'Cluster ID': 5, 'confidence_score': 0.9846},
#  16: {'Cluster ID': 5, 'confidence_score': 0.9846},
#  0: {'Cluster ID': 6, 'confidence_score': 1.0},
#  5: {'Cluster ID': 7, 'confidence_score': 1.0},
#  6: {'Cluster ID': 8, 'confidence_score': 1.0},
#  9: {'Cluster ID': 9, 'confidence_score': 1.0},
#  10: {'Cluster ID': 10, 'confidence_score': 1.0},
#  17: {'Cluster ID': 11, 'confidence_score': 1.0},
#  18: {'Cluster ID': 12, 'confidence_score': 1.0},
#  19: {'Cluster ID': 13, 'confidence_score': 1.0},
#  20: {'Cluster ID': 14, 'confidence_score': 1.0},
#  21: {'Cluster ID': 15, 'confidence_score': 1.0},
#  22: {'Cluster ID': 16, 'confidence_score': 1.0},
#  23: {'Cluster ID': 17, 'confidence_score': 1.0},
#  24: {'Cluster ID': 18, 'confidence_score': 1.0},
#  25: {'Cluster ID': 19, 'confidence_score': 1.0},
#  26: {'Cluster ID': 20, 'confidence_score': 1.0},
#  27: {'Cluster ID': 21, 'confidence_score': 1.0},
#  28: {'Cluster ID': 22, 'confidence_score': 1.0},
#  29: {'Cluster ID': 23, 'confidence_score': 1.0},
#  30: {'Cluster ID': 24, 'confidence_score': 1.0},
#  31: {'Cluster ID': 25, 'confidence_score': 1.0},
#  32: {'Cluster ID': 26, 'confidence_score': 1.0}}

# %%
# To use the id column
df.to_csv('restaurant-training-opt.csv', index=False)

# %%
input_file = 'restaurant-training-opt.csv'
output_file = 'restaurant_training_output.csv'

# %%
# Writing the results
with open(output_file, 'w') as f_output, open(input_file) as f_input:
    reader = csv.DictReader(f_input)
    fieldnames = ['Cluster ID', 'confidence_score'] + reader.fieldnames

    writer = csv.DictWriter(f_output, fieldnames=fieldnames)
    writer.writeheader()

    for row in reader:
        row_id = int(row['id'])
        row.update(cluster_membership[row_id])
        writer.writerow(row)
